# %%
# !pip install numpy==1.16.2
# La versión 1.16.3 de numpy tiene allow_pickle = True
# Out:
# Requirement already satisfied: numpy==1.16.2 in /usr/local/lib/python3.6/dist-packages (1.16.2)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
# !pip install easy-rouge
# Out:
# Collecting easy-rouge
#   Downloading https://files.pythonhosted.org/packages/0c/0a/b7ebb887dac3ece27fffc65bbc7dc0abcf991f2ccce8073126329ce4be8f/easy_rouge-0.2.2-py3-none-any.whl
# Installing collected packages: easy-rouge
# Successfully installed easy-rouge-0.2.2

# %%
def summary_evaluation_ROUGEN(docs_per_sentence, gold_per_sentence, n_rouge):

  from rouge.rouge import rouge_n_sentence_level

  def prepare_results(r, p, f, n_rouge):
      return '\t{}:{:5.4f}\t{}: {:5.4f}\t{}: {:5.4f}'.format('ROUGE{}-recall'.format(n_rouge), r, 'ROUGE{}-precision'.format(n_rouge), p, 'ROUGE{}-F1 score'.format(n_rouge), f)

  j = 0
  RN_recall_total = []
  RN_precision_total = []
  RN_fscore_total = []

  # for j in range(len(docs_per_sentence)):
      
  RN_recall, RN_precision, RN_fscore = rouge_n_sentence_level(docs_per_sentence[j], gold_per_sentence[j], n_rouge, 1)
  RN_recall_total.append(RN_recall)
  RN_precision_total.append(RN_precision)
  RN_fscore_total.append(RN_fscore)
  
  print(prepare_results(RN_recall, RN_precision, RN_fscore, n_rouge))
  
  return RN_recall_total, RN_precision_total, RN_fscore_total

# %%
# import numpy as np
common_path = '/content/gdrive/My Drive/Codigos_doctorado_DUC2001/'
nrouge1 = 1
nrouge2 = 2
sent_per_collection = open(common_path + 'toy_example_summary2b/' + 'd101e_englishSyssum1.txt', 'r').readlines()
gold_std = open(common_path + 'toy_example_summary2b/' + 'd101e_englishReference1.txt', 'r').readlines()
R1_recall_total, R1_precision_total, R1_fscore_total = summary_evaluation_ROUGEN(sent_per_collection, gold_std, nrouge1)
R2_recall_total, R2_precision_total, R2_fscore_total = summary_evaluation_ROUGEN(sent_per_collection, gold_std, nrouge2)
# print(R1_recall_total, R2_recall_total, R1_fscore_total)
# Out:
# 	ROUGE1-recall:0.9860	ROUGE1-precision: 0.7460	ROUGE1-F1 score: 0.7460
# 	ROUGE2-recall:0.9719	ROUGE2-precision: 0.7347	ROUGE2-F1 score: 0.7347

# %%
print(gold_std)
# Out:
# ['Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail.\n', 'Gorbachev Gorbachev Gorbachev Gorbachev Gorbachev Gorbachev Gorbachev Gorbachev Gorbachev.\n', 'Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin.']

# %%
print(sent_per_collection)
# Out:
# ['Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail Mikhail.\n', 'Gorbachev Gorbachev Gorbachev Gorbachev Gorbachev Gorbachev Gorbachev Gorbachev Gorbachev.\n', 'Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin Yeltsin.']
