# %%
# !pip install numpy==1.16.2
# La versión 1.16.3 de numpy tiene allow_pickle = True

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# from https://github.com/pltrdy/rouge
# !pip install rouge

# %%
import numpy as np
# folder name for DUC 2004
common_path = common_path = "/content/gdrive/My Drive/Codigos_doctorado_DUC2004/"
files_names = np.load("/content/gdrive/My Drive/Codigos_doctorado_DUC2001/" + 'files_names_longitude_DUC2004' + '.npy')
ic = np.load(common_path + 'colecciones_testing_DUC2004_pyrouge.npy')
foname = np.load(common_path + 'folder_name_2004' + '.npy')
golda = np.load(common_path + 'gold_a_2004' + '.npy')
goldb = np.load(common_path + 'gold_b_2004' + '.npy')
goldc = np.load(common_path + 'gold_c_2004' + '.npy')
goldd = np.load(common_path + 'gold_d_2004' + '.npy')

# %%
aux_files_a = []
aux_files_b = []
aux_files_c = []
aux_files_d = []

aux = files_names.tolist()
aux2 = sorted(aux)

for i in range(len(aux2)):
  if i%4 == 0:
    aux_files_a.append(aux2[i])
    #golda.append(gold[i])

for i in range(len(aux2)):
  if i%4 == 1:
    aux_files_b.append(aux2[i])
    #goldb.append(gold[i])

for i in range(len(aux2)):
  if i%4 == 2:
    aux_files_c.append(aux2[i])
    #goldc.append(gold[i])

for i in range(len(aux2)):
  if i%4 == 3:
    aux_files_d.append(aux2[i])
    #goldd.append(gold[i])

# %%
# dividing gold standards for DUC 2004 testing collection
aux = ic.tolist()
aux2 = sorted(aux)

gold_a_test = []
gold_b_test = []
gold_c_test = []
gold_d_test = []

aux2_a = []
aux2_b = []
aux2_c = []
aux2_d = []

for i in range(len(aux2)):
  gold_a_test.append(golda[aux2[i]])
  gold_b_test.append(goldb[aux2[i]])
  gold_c_test.append(goldc[aux2[i]])
  gold_d_test.append(goldd[aux2[i]])

  aux2_a.append(aux_files_a[aux2[i]])
  aux2_b.append(aux_files_b[aux2[i]])
  aux2_c.append(aux_files_c[aux2[i]])
  aux2_d.append(aux_files_d[aux2[i]])

# %%
aux_foname = []
for i in range(len(aux2)):
  aux_foname.append(foname[aux2[i]])

# print(aux_foname)

# %%
###### delete sentences in system summary for DUC 2004 balanced MLP-relu pyrouge
common_path = '/content/gdrive/My Drive/Codigos_doctorado_DUC2004/'
import os

for i in range(len(gold_a_test)):

  # for DUC 2001 Original approach unbalanced MLP-relu
  #goldfile = open(common_path + 'model_summariesA_2004_sup/' + '{}_englishReference1.txt'.format(aux2_a[i]), 'r').readlines()
  #goldfile = open(common_path + 'model_summariesB_2004_sup/' + '{}_englishReference1.txt'.format(aux2_b[i]), 'r').readlines()
  #goldfile = open(common_path + 'model_summariesC_2004_sup/' + '{}_englishReference1.txt'.format(aux2_c[i]), 'r').readlines()
  goldfile = open(common_path + 'model_summariesD_2004_sup/' + '{}_englishReference1.txt'.format(aux2_d[i]), 'r').readlines()
 
  # for DUC 2004
  num_cl = 4
  infile = open(common_path + 'testing_2004_classifier_for_pltrdy_{}_0/'.format(num_cl) + 'GaussianNB_200_LEMA_{}/'.format(0) + '{}_englishSyssum1.txt'.format(aux_foname[i]), 'r').readlines()

  # print(i, len(goldfile), len(infile))

  # for DUC 2004
  #folder = 'summaries_cl{}_for_ROUGE_pltrdy_A_DUC2004_pyrouge/'.format(num_cl)
  #folder = 'summaries_cl{}_for_ROUGE_pltrdy_B_DUC2004_pyrouge/'.format(num_cl)
  #folder = 'summaries_cl{}_for_ROUGE_pltrdy_C_DUC2004_pyrouge/'.format(num_cl)
  folder = 'summaries_cl{}_for_ROUGE_pltrdy_D_DUC2004_pyrouge/'.format(num_cl)
  if os.path.exists(common_path + folder) == False:
    os.mkdir(common_path + folder)

  file_name = '{}_englishSyssum1.txt'.format(aux_foname[i])

  with open(common_path + folder + file_name, 'w') as outfile:
    for index, line in enumerate(infile):
      if index < len(goldfile):
        outfile.write(line)

# %%
for i in range(len(gold_a_test)):

  # for DUC 2004 unbalanced MLP-relu
  #goldfile = open(common_path + 'model_summariesA_2004_sup/' + '{}_englishReference1.txt'.format(aux2_a[i]), 'r').readlines()
  #goldfile = open(common_path + 'model_summariesB_2004_sup/' + '{}_englishReference1.txt'.format(aux2_b[i]), 'r').readlines()
  #goldfile = open(common_path + 'model_summariesC_2004_sup/' + '{}_englishReference1.txt'.format(aux2_c[i]), 'r').readlines()
  goldfile = open(common_path + 'model_summariesD_2004_sup/' + '{}_englishReference1.txt'.format(aux2_d[i]), 'r').readlines()
 
  # for DUC 2004
  num_cl = 4
  #infile = open(common_path + 'summaries_cl{}_for_ROUGE_pltrdy_A_DUC2004_pyrouge/'.format(num_cl) + '{}_englishSyssum1.txt'.format(aux_foname[i]), 'r').readlines()
  #infile = open(common_path + 'summaries_cl{}_for_ROUGE_pltrdy_B_DUC2004_pyrouge/'.format(num_cl) + '{}_englishSyssum1.txt'.format(aux_foname[i]), 'r').readlines()
  #infile = open(common_path + 'summaries_cl{}_for_ROUGE_pltrdy_C_DUC2004_pyrouge/'.format(num_cl) + '{}_englishSyssum1.txt'.format(aux_foname[i]), 'r').readlines()
  infile = open(common_path + 'summaries_cl{}_for_ROUGE_pltrdy_D_DUC2004_pyrouge/'.format(num_cl) + '{}_englishSyssum1.txt'.format(aux_foname[i]), 'r').readlines()

  # print(i, len(goldfile), len(infile))

# %%
common_path = '/content/gdrive/My Drive/Codigos_doctorado_DUC2004/'
scores = []
aux_rouge1_r = 0
aux_rouge1_p = 0
aux_rouge1_f = 0
aux_rouge2_r = 0
aux_rouge2_p = 0
aux_rouge2_f = 0
aux2_rouge1_r = []
aux2_rouge1_p = []
aux2_rouge1_f = []
aux2_rouge2_r = []
aux2_rouge2_p = []
aux2_rouge2_f = []

num_cl = 4
foname = aux2_a

for j in range(len(aux_foname)): # for DUC 2004

  # print(j)
  # for DUC 2004 A
  #hyp_path = common_path + 'summaries_cl{}_for_ROUGE_pltrdy_A_DUC2004_pyrouge/'.format(num_cl) + '{}_englishSyssum1.txt'.format(aux_foname[j])
  #ref_path = common_path + 'model_summariesA_2004_sup/' + '{}_englishReference1.txt'.format(aux2_a[j])

  # for DUC 2004 B
  #hyp_path = common_path + 'summaries_cl{}_for_ROUGE_pltrdy_B_DUC2004_pyrouge/'.format(num_cl) + '{}_englishSyssum1.txt'.format(aux_foname[j])
  #ref_path = common_path + 'model_summariesB_2004_sup/' + '{}_englishReference1.txt'.format(aux2_b[j])

  # for DUC 2004 C
  #hyp_path = common_path + 'summaries_cl{}_for_ROUGE_pltrdy_C_DUC2004_pyrouge/'.format(num_cl) + '{}_englishSyssum1.txt'.format(aux_foname[j])
  #ref_path = common_path + 'model_summariesC_2004_sup/' + '{}_englishReference1.txt'.format(aux2_c[j])

  # for DUC 2004 D
  hyp_path = common_path + 'summaries_cl{}_for_ROUGE_pltrdy_D_DUC2004_pyrouge/'.format(num_cl) + '{}_englishSyssum1.txt'.format(aux_foname[j])
  ref_path = common_path + 'model_summariesD_2004_sup/' + '{}_englishReference1.txt'.format(aux2_d[j])


  from rouge import FilesRouge

  files_rouge = FilesRouge(hyp_path, ref_path)
  scores = files_rouge.get_scores()
  # or
  # scores = files_rouge.get_scores(avg=True)

  for i in range(len(scores)):
    # print(i)
    aux_rouge1_r += scores[i]['rouge-1']['r'] #ROUGE-1 recall
    aux_rouge1_p += scores[i]['rouge-1']['p'] #ROUGE-1 precision
    aux_rouge1_f += scores[i]['rouge-1']['f'] #ROUGE-1 F1 score
    aux_rouge2_r += scores[i]['rouge-2']['r'] #ROUGE-2 recall
    aux_rouge2_p += scores[i]['rouge-2']['p'] #ROUGE-2 precision
    aux_rouge2_f += scores[i]['rouge-2']['f'] #ROUGE-2 F1 score

  # print(j, '{:5.4f}'.format(aux_rouge1/len(scores)))
  # print('{:5.4f}'.format(aux_rouge2/len(scores)))
  # print('{:5.4f}'.format(aux_fscore/len(scores)))

  aux2_rouge1_r.append(aux_rouge1_r/len(scores))
  aux2_rouge1_p.append(aux_rouge1_p/len(scores))
  aux2_rouge1_f.append(aux_rouge1_f/len(scores))
  aux2_rouge2_r.append(aux_rouge2_r/len(scores))
  aux2_rouge2_p.append(aux_rouge2_p/len(scores))
  aux2_rouge2_f.append(aux_rouge2_f/len(scores))

  aux_rouge1_r = 0
  aux_rouge1_p = 0
  aux_rouge1_f = 0
  aux_rouge2_r = 0
  aux_rouge2_p = 0
  aux_rouge2_f = 0

print('ROUGE-1 recall = {:5.4f}'.format(sum(aux2_rouge1_r)/len(foname)))
print('ROUGE-1 precision = {:5.4f}'.format(sum(aux2_rouge1_p)/len(foname)))
print('ROUGE-1 F1 score = {:5.4f}'.format(sum(aux2_rouge1_f)/len(foname)))
print('ROUGE-2 recall = {:5.4f}'.format(sum(aux2_rouge2_r)/len(foname)))
print('ROUGE-2 precision = {:5.4f}'.format(sum(aux2_rouge2_p)/len(foname)))
print('ROUGE-2 F1 score = {:5.4f}'.format(sum(aux2_rouge2_f)/len(foname)))

#np.save(common_path + 'ROUGE1_F1score_DUC2004A_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_f)/len(foname))
#np.save(common_path + 'ROUGE1_recall_DUC2004A_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_r)/len(foname))
#np.save(common_path + 'ROUGE1_precision_DUC2004A_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_p)/len(foname))
#np.save(common_path + 'ROUGE2_recall_DUC2004A_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_r)/len(foname))
#np.save(common_path + 'ROUGE2_precision_DUC2004A_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_p)/len(foname))
#np.save(common_path + 'ROUGE2_F1score_DUC2004A_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_f)/len(foname))

#np.save(common_path + 'ROUGE1_recall_DUC2004B_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_r)/len(foname))
#np.save(common_path + 'ROUGE1_F1score_DUC2004B_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_f)/len(foname))
#np.save(common_path + 'ROUGE1_precision_DUC2004B_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_p)/len(foname))
#np.save(common_path + 'ROUGE2_recall_DUC2004B_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_r)/len(foname))
#np.save(common_path + 'ROUGE2_precision_DUC2004B_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_p)/len(foname))
#np.save(common_path + 'ROUGE2_F1score_DUC2004B_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_f)/len(foname))

#np.save(common_path + 'ROUGE1_F1score_DUC2004C_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_f)/len(foname))
#np.save(common_path + 'ROUGE1_recall_DUC2004C_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_r)/len(foname))
#np.save(common_path + 'ROUGE1_precision_DUC2004C_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_p)/len(foname))
#np.save(common_path + 'ROUGE2_recall_DUC2004C_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_r)/len(foname))
#np.save(common_path + 'ROUGE2_precision_DUC2004C_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_p)/len(foname))
#np.save(common_path + 'ROUGE2_F1score_DUC2004C_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_f)/len(foname))

np.save(common_path + 'ROUGE1_recall_DUC2004D_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_r)/len(foname))
np.save(common_path + 'ROUGE1_precision_DUC2004D_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_p)/len(foname))
np.save(common_path + 'ROUGE1_F1score_DUC2004D_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_f)/len(foname))
np.save(common_path + 'ROUGE2_recall_DUC2004D_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_r)/len(foname))
np.save(common_path + 'ROUGE2_precision_DUC2004D_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_p)/len(foname))
np.save(common_path + 'ROUGE2_F1score_DUC2004D_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_f)/len(foname))
# Out:
# ROUGE-1 recall = 0.1736
# ROUGE-1 precision = 0.0843
# ROUGE-1 F1 score = 0.1089
# ROUGE-2 recall = 0.0098
# ROUGE-2 precision = 0.0043
# ROUGE-2 F1 score = 0.0058

# %%
import numpy as np

common_path = '/content/gdrive/My Drive/Codigos_doctorado_DUC2004/'
num_cl = 4

r1_r_a = np.load(common_path + 'ROUGE1_recall_DUC2004A_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r1_p_a = np.load(common_path + 'ROUGE1_precision_DUC2004A_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r1_f_a = np.load(common_path + 'ROUGE1_F1score_DUC2004A_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r2_r_a = np.load(common_path + 'ROUGE2_recall_DUC2004A_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r2_p_a = np.load(common_path + 'ROUGE2_precision_DUC2004A_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r2_f_a = np.load(common_path + 'ROUGE2_F1score_DUC2004A_sup_cl{}_pyrouge'.format(num_cl) + '.npy')

r1_r_b = np.load(common_path + 'ROUGE1_recall_DUC2004B_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r1_p_b = np.load(common_path + 'ROUGE1_F1score_DUC2004B_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r1_f_b = np.load(common_path + 'ROUGE1_precision_DUC2004B_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r2_r_b = np.load(common_path + 'ROUGE2_recall_DUC2004B_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r2_p_b = np.load(common_path + 'ROUGE2_precision_DUC2004B_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r2_f_b = np.load(common_path + 'ROUGE2_F1score_DUC2004B_sup_cl{}_pyrouge'.format(num_cl) + '.npy')

r1_r_c = np.load(common_path + 'ROUGE1_F1score_DUC2004C_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r1_p_c = np.load(common_path + 'ROUGE1_recall_DUC2004C_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r1_f_c = np.load(common_path + 'ROUGE1_precision_DUC2004C_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r2_r_c = np.load(common_path + 'ROUGE2_recall_DUC2004C_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r2_p_c = np.load(common_path + 'ROUGE2_precision_DUC2004C_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r2_f_c = np.load(common_path + 'ROUGE2_F1score_DUC2004C_sup_cl{}_pyrouge'.format(num_cl) + '.npy')

r1_r_d = np.load(common_path + 'ROUGE1_recall_DUC2004D_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r1_p_d = np.load(common_path + 'ROUGE1_precision_DUC2004D_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r1_f_d = np.load(common_path + 'ROUGE1_F1score_DUC2004D_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r2_r_d = np.load(common_path + 'ROUGE2_recall_DUC2004D_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r2_p_d = np.load(common_path + 'ROUGE2_precision_DUC2004D_sup_cl{}_pyrouge'.format(num_cl) + '.npy')
r2_f_d = np.load(common_path + 'ROUGE2_F1score_DUC2004D_sup_cl{}_pyrouge'.format(num_cl) + '.npy')


print((r1_r_a + r1_r_b + r1_r_c + r1_r_d)/4)
print((r1_p_a + r1_p_b + r1_p_c + r1_p_d)/4)
print((r1_f_a + r1_f_b + r1_f_c + r1_f_d)/4)

print((r2_r_a + r2_r_b + r2_r_c + r2_r_d)/4)
print((r2_p_a + r2_p_b + r2_p_c + r2_p_d)/4)
print((r2_f_a + r2_f_b + r2_f_c + r2_f_d)/4)
# Out:
# 0.16114924845676035
# 0.11636806198789118
# 0.1008107319414365
# 0.016760472052321562
# 0.009530831235635112
# 0.011669272156736943
