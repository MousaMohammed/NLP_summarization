# %%
# !pip install numpy==1.16.2
# La versión 1.16.3 de numpy tiene allow_pickle = True

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# from https://github.com/pltrdy/rouge
# !pip install rouge

# %%
common_path = '/content/gdrive/My Drive/Codigos_doctorado_DUC2001/'
# hyp_path = common_path + 'testing_classifier_test_30collectionALL_4_0/GaussianNB_200_LEMA_0/d04a_englishSyssum1.txt'
# ref_path = common_path + 'DUC_2001_testing_gold_standard_doubles_filtered/d04ab_englishReference1.txt'

# hyp_path = common_path + 'd061j_englishSyssum1.txt'
# ref_path = common_path + 'd061j_englishReference1.txt'

# hyp_path = common_path + 'toy_example_summary/' + 'd101e_englishSyssum1.txt'
# ref_path = common_path + 'toy_example_summary/' + 'd101e_englishReference1.txt'

# hyp_path = common_path + 'toy_example_no_punctuation_summary/' + 'd101e_englishSyssum1.txt'
# ref_path = common_path + 'toy_example_no_punctuation_summary/' + 'd101e_englishReference1.txt'

# hyp_path = common_path + 'toy_example_one_sentence_format_summary/' + 'd101e_englishSyssum1.txt'
# ref_path = common_path + 'toy_example_one_sentence_format_summary/' + 'd101e_englishReference1.txt'

# hyp_path = common_path + 'toy_example_summary2/' + 'd101e_englishSyssum1.txt'
# ref_path = common_path + 'toy_example_summary2/' + 'd101e_englishReference1.txt'

# hyp_path = common_path + 'toy_example_summary2_a/' + 'd101e_englishSyssum1.txt'
# ref_path = common_path + 'toy_example_summary2_a/' + 'd101e_englishReference1.txt'

# hyp_path = common_path + 'toy_example_summary2b/' + 'd101e_englishSyssum1.txt'
# ref_path = common_path + 'toy_example_summary2b/' + 'd101e_englishReference1.txt'

# %%
import numpy as np
# folder name for DUC 2002
foname = np.load('/content/gdrive/My Drive/Codigos_doctorado/' + 'folder_name' + '.npy')
# folder name for DUC 2001
#foname2 = np.load('/content/gdrive/My Drive/Codigos_doctorado_DUC2001/' + 'files_names_DUC2001' + '.npy') #for gold standards
#foname = np.load(common_path + 'folder_name_2001_testing' + '.npy') # for testing collection
#aux_foname2 = np.load(common_path + 'files_names_longitude_DUC2001' + '.npy')

# %%
# dividing gold standards for DUC 2001 testing collection
foname_goldA = []
foname_goldB = []

for i in range(len(foname2)):
  aux = i%2
  if aux != 0:
#     print(i)
    foname_goldB.append(foname2[i]) 
  else:
    foname_goldA.append(foname2[i])

# %%
print(foname)
# Out:
# ['d061j' 'd062j' 'd063j' 'd064j' 'd065j' 'd066j' 'd067f' 'd068f' 'd069f'
#  'd070f' 'd071f' 'd072f' 'd073b' 'd074b' 'd075b' 'd077b' 'd078b' 'd079a'
#  'd080a' 'd081a' 'd082a' 'd083a' 'd084a' 'd085d' 'd086d' 'd087d' 'd089d'
#  'd090d' 'd091c' 'd092c' 'd093c' 'd094c' 'd095c' 'd096c' 'd097e' 'd099e'
#  'd100e' 'd101e' 'd102e' 'd103g' 'd104g' 'd105g' 'd106g' 'd107g' 'd108g'
#  'd109h' 'd110h' 'd111h' 'd112h' 'd113h' 'd114h' 'd115i' 'd116i' 'd117i'
#  'd118i' 'd119i' 'd120i']

# %%
print(foname)
# Out:
# ['d061j' 'd062j' 'd063j' 'd064j' 'd065j' 'd066j' 'd067f' 'd068f' 'd069f'
#  'd070f' 'd071f' 'd072f' 'd073b' 'd074b' 'd075b' 'd077b' 'd078b' 'd079a'
#  'd080a' 'd081a' 'd082a' 'd083a' 'd084a' 'd085d' 'd086d' 'd087d' 'd089d'
#  'd090d' 'd091c' 'd092c' 'd093c' 'd094c' 'd095c' 'd096c' 'd097e' 'd099e'
#  'd100e' 'd101e' 'd102e' 'd103g' 'd104g' 'd105g' 'd106g' 'd107g' 'd108g'
#  'd109h' 'd110h' 'd111h' 'd112h' 'd113h' 'd114h' 'd115i' 'd116i' 'd117i'
#  'd118i' 'd119i' 'd120i']

# %%
print(foname2)

# %%
print(foname_goldA)
# Out:
# ['d04ab', 'd05ac', 'd06ad', 'd08bc', 'd11be', 'd12be', 'd13ce', 'd14cb', 'd15ci', 'd19da', 'd22db', 'd24dc', 'd27ea', 'd28eh', 'd30ed', 'd31fg', 'd32fg', 'd34fh', 'd37ga', 'd39gc', 'd41gd', 'd43hc', 'd44ha', 'd45ha', 'd50ib', 'd53id', 'd54ib', 'd56ka', 'd57kd', 'd59ke']

# %%
###### delete sentences in system summary for DUC 2001 Original approach balanced MLP-relu pyrouge
common_path = '/content/gdrive/My Drive/Codigos_doctorado_DUC2001/'
import os

for i in range(len(foname)):

  # for DUC 2001 Original approach unbalanced MLP-relu
  #goldfile = open(common_path + 'DUC_2001_testing_gold_standard_doubles_filtered/' + '{}_englishReference1.txt'.format(foname_goldA[i]), 'r').readlines()
  goldfile = open(common_path + 'DUC_2001_testing_gold_standard_doubles_filtered/' + '{}_englishReference1.txt'.format(foname_goldB[i]), 'r').readlines()
 
  # for DUC 2001
  num_cl = 4
  infile = open(common_path + 'testing_for_pltrdy_classifier_test_30collectionALL_pyrouge_{}_0/'.format(num_cl) + 'GaussianNB_200_LEMA_{}/'.format(0) + '{}_englishSyssum1.txt'.format(foname[i]), 'r').readlines()

  #print(i, len(goldfile), len(infile))

  # for DUC 2001
  #folder = 'summaries_cl{}_for_ROUGE_pltrdy_A_DUC2001_pyrouge/'.format(num_cl)
  folder = 'summaries_cl{}_for_ROUGE_pltrdy_B_DUC2001_pyrouge/'.format(num_cl)
  if os.path.exists(common_path + folder) == False:
    os.mkdir(common_path + folder)

  file_name = '{}_englishSyssum1.txt'.format(foname[i])

  with open(common_path + folder + file_name, 'w') as outfile:
    for index, line in enumerate(infile):
      if index < len(goldfile):
        outfile.write(line)

# %%
###### delete sentences in system summary for DUC 2001 Original approach balanced MLP-relu
common_path = '/content/gdrive/My Drive/Codigos_doctorado_DUC2001/'
import os

for i in range(len(foname)):

  # for DUC 2001 Original approach balanced MLP-relu
  #goldfile = open(common_path + 'DUC_2001_testing_gold_standard_doubles_filtered/' + '{}_englishReference1.txt'.format(foname_goldA[i]), 'r').readlines()
  goldfile = open(common_path + 'DUC_2001_testing_gold_standard_doubles_filtered/' + '{}_englishReference1.txt'.format(foname_goldB[i]), 'r').readlines()
 
  # for DUC 2001
  num_cl = 4
  infile = open(common_path + 'testing_for_pltrdy_no_batches_classifier_test_30collectionALL_{}/'.format(num_cl) + 'GaussianNB_200_LEMA_{}/'.format(num_cl) + '{}_englishSyssum1.txt'.format(foname[i]), 'r').readlines()

  # print(i, len(goldfile), len(infile))

  # for DUC 2001
  #folder = 'summaries_cl{}_for_ROUGE_pltrdy_A_DUC2001/'.format(num_cl)
  folder = 'summaries_cl{}_for_ROUGE_pltrdy_B_DUC2001/'.format(num_cl)
  if os.path.exists(common_path + folder) == False:
    os.mkdir(common_path + folder)

  file_name = '{}_englishSyssum1.txt'.format(foname[i])

  with open(common_path + folder + file_name, 'w') as outfile:
    for index, line in enumerate(infile):
      if index < len(goldfile):
        outfile.write(line)

# %%
###### delete sentences in system summary for DUC 2002 CluAggloRoulD unsup (30 experiments)
common_path = '/content/gdrive/My Drive/Codigos_doctorado_unsupervised_best/'
import os

for j in range(30):
  for i in range(len(foname)):

    # for DUC 2002 CluAggloRoulD (30 experiments)
    goldfile = open('/content/gdrive/My Drive/Codigos_doctorado_DUC2001/' + 'gold_standardA_DUC2002/' + '{}_englishReference1.txt'.format(foname[i]), 'r').readlines()
    # goldfile = open('/content/gdrive/My Drive/Codigos_doctorado_DUC2001/' + 'gold_standardB_DUC2002/' + '{}_englishReference1.txt'.format(foname[i]), 'r').readlines()

    # for DUC 2002
    infile = open(common_path + 'CluAgglo_RoulD_DUC2002_resumenes2/' + 'CluAgglo_RoulD_resumenes_{}/'.format(j) + '{}_englishSyssum1.txt'.format(foname[i]), 'r').readlines()
    
    # for DUC 2002
    folder = 'summaries_for_ROUGE_pltrdy_A_DUC2002/'
    if os.path.exists(common_path + folder) == False:
      os.mkdir(common_path + folder)

    folder2 = 'CluAgglo_RoulD_resumenes_{}/'.format(j)
    if os.path.exists(common_path + folder + folder2) == False:
      os.mkdir(common_path + folder + folder2)

    # print(i, len(goldfile), len(infile))

    file_name = '{}_englishSyssum1.txt'.format(foname[i])

    with open(common_path + folder + folder2 + file_name, 'w') as outfile:
      for index, line in enumerate(infile):
        if index < len(goldfile):
          outfile.write(line)

# %%
ic = np.load('/content/gdrive/My Drive/Codigos_doctorado/' + 'colecciones_testing.npy')
print(ic)

foname_duc2002_sup = []
for i in range(len(ic)):
  foname_duc2002_sup.append(foname[ic[i]])

print(foname_duc2002_sup)
# Out:
# [18 19 20 21 24 31 37 44 49 50 52]
# ['d080a', 'd081a', 'd082a', 'd083a', 'd086d', 'd094c', 'd101e', 'd108g', 'd113h', 'd114h', 'd116i']

# %%
###### delete sentences in system summary for DUC 2002 supervised
common_path = '/content/gdrive/My Drive/Codigos_doctorado_DUC2001/'
import os

for i in range(len(foname_duc2002_sup)):

  # for DUC 2002
  goldfile = open('/content/gdrive/My Drive/Codigos_doctorado_DUC2001/' + 'model_summariesA_2002_sup/' + '{}_englishReference1.txt'.format(foname_duc2002_sup[i]), 'r').readlines()
  # goldfile = open('/content/gdrive/My Drive/Codigos_doctorado_DUC2001/' + 'model_summariesB_2002_sup/' + '{}_englishReference1.txt'.format(foname_duc2002_sup[i]), 'r').readlines()

  # for DUC 2002
  num_cl = 3
  infile = open('/content/gdrive/My Drive/Codigos_doctorado/' + 'testing1_no_batches_extra_sentences_classifierALL_{}/'.format(num_cl) + 'GaussianNB_200_LEMA_{}/'.format(num_cl) +  '{}_englishSyssum1.txt'.format(foname_duc2002_sup[i]), 'r').readlines()
  
  # for DUC 2002
  folder = 'summaries_for_ROUGE_pltrdy_A_DUC2002_supervised_{}/'.format(num_cl)
  if os.path.exists(common_path + folder) == False:
    os.mkdir(common_path + folder)

  # print(i, len(goldfile), len(infile))

  file_name = '{}_englishSyssum1.txt'.format(foname_duc2002_sup[i])

  with open(common_path + folder + file_name, 'w') as outfile:
    for index, line in enumerate(infile):
      if index < len(goldfile):
        outfile.write(line)

# %%
from rouge import FilesRouge

files_rouge = FilesRouge(hyp_path, ref_path)
scores = files_rouge.get_scores()
# or
# scores = files_rouge.get_scores(avg=True)
aux_rouge1 = 0
aux_rouge2 = 0
aux_fscore = 0
for i in range(len(scores)):
  # print(i)
  aux_rouge1 += scores[i]['rouge-1']['r']
  aux_fscore += scores[i]['rouge-1']['f']
  aux_rouge2 += scores[i]['rouge-2']['r']
print('{:5.4f}'.format(aux_rouge1/len(scores)))
print('{:5.4f}'.format(aux_rouge2/len(scores)))
print('{:5.4f}'.format(aux_fscore/len(scores)))

# %%
from rouge import FilesRouge

files_rouge = FilesRouge(hyp_path, ref_path)
scores = files_rouge.get_scores()
print(scores)
# Out:
# [{'rouge-1': {'f': 0.999999995, 'p': 1.0, 'r': 1.0}, 'rouge-2': {'f': 0.999999995, 'p': 1.0, 'r': 1.0}, 'rouge-l': {'f': 0.9999999999995, 'p': 1.0, 'r': 1.0}}, {'rouge-1': {'f': 0.999999995, 'p': 1.0, 'r': 1.0}, 'rouge-2': {'f': 0.999999995, 'p': 1.0, 'r': 1.0}, 'rouge-l': {'f': 0.9999999999995, 'p': 1.0, 'r': 1.0}}, {'rouge-1': {'f': 0.999999995, 'p': 1.0, 'r': 1.0}, 'rouge-2': {'f': 0.999999995, 'p': 1.0, 'r': 1.0}, 'rouge-l': {'f': 0.9999999999995, 'p': 1.0, 'r': 1.0}}]

# %%
print(len(hyp_path), len(ref_path))
# Out:
# 112 121

# %%
common_path = '/content/gdrive/My Drive/Codigos_doctorado_DUC2001/'
scores = []
aux_rouge1_r = 0
aux_rouge1_p = 0
aux_rouge1_f = 0
aux_rouge2_r = 0
aux_rouge2_p = 0
aux_rouge2_f = 0
aux2_rouge1_r = []
aux2_rouge1_p = []
aux2_rouge1_f = []
aux2_rouge2_r = []
aux2_rouge2_p = []
aux2_rouge2_f = []

num_cl = 3

#for j in range(len(foname)): # for DUC 2001
for j in range(len(foname_duc2002_sup)): # for DUC 2002

  # print(j)
  # for DUC 2002 A
  #hyp_path = common_path + 'summaries_for_ROUGE_pltrdy_A_DUC2002_supervised_{}/'.format(num_cl) + '{}_englishSyssum1.txt'.format(foname_duc2002_sup[j])
  #ref_path = common_path + 'model_summariesA_2002_sup/' + '{}_englishReference1.txt'.format(foname_duc2002_sup[j])

  # for DUC 2002 B
  hyp_path = common_path + 'summaries_for_ROUGE_pltrdy_B_DUC2002_supervised_{}/'.format(num_cl) + '{}_englishSyssum1.txt'.format(foname_duc2002_sup[j])
  ref_path = common_path + 'model_summariesB_2002_sup/' + '{}_englishReference1.txt'.format(foname_duc2002_sup[j])

  # for DUC 2001 A
  #folder = 'summaries_cl{}_for_ROUGE_pltrdy_A_DUC2001/'.format(num_cl)
  #hyp_path = common_path + folder + '{}_englishSyssum1.txt'.format(foname[j])
  #ref_path = common_path + 'DUC_2001_testing_gold_standard_doubles_filtered/' + '{}_englishReference1.txt'.format(foname_goldA[j])

  # for DUC 2001 B
  #folder = 'summaries_cl{}_for_ROUGE_pltrdy_B_DUC2001/'.format(num_cl)
  #hyp_path = common_path + folder + '{}_englishSyssum1.txt'.format(foname[j])
  #ref_path = common_path + 'DUC_2001_testing_gold_standard_doubles_filtered/' + '{}_englishReference1.txt'.format(foname_goldB[j])
  
  # for DUC 2001 A pyrouge
  #folder = 'summaries_cl{}_for_ROUGE_pltrdy_A_DUC2001_pyrouge/'.format(num_cl)
  #hyp_path = common_path + folder + '{}_englishSyssum1.txt'.format(foname[j])
  #ref_path = common_path + 'DUC_2001_testing_gold_standard_doubles_filtered/' + '{}_englishReference1.txt'.format(foname_goldA[j])

  # for DUC 2001 B pyrouge
  #folder = 'summaries_cl{}_for_ROUGE_pltrdy_B_DUC2001_pyrouge/'.format(num_cl)
  #ref_path = common_path + 'DUC_2001_testing_gold_standard_doubles_filtered/' + '{}_englishReference1.txt'.format(foname_goldB[j])
  #hyp_path = common_path + folder + '{}_englishSyssum1.txt'.format(foname[j])



  from rouge import FilesRouge

  files_rouge = FilesRouge(hyp_path, ref_path)
  scores = files_rouge.get_scores()
  # or
  # scores = files_rouge.get_scores(avg=True)

  for i in range(len(scores)):
    # print(i)
    aux_rouge1_r += scores[i]['rouge-1']['r'] #ROUGE-1 recall
    aux_rouge1_p += scores[i]['rouge-1']['p'] #ROUGE-1 precision
    aux_rouge1_f += scores[i]['rouge-1']['f'] #ROUGE-1 F1 score
    aux_rouge2_r += scores[i]['rouge-2']['r'] #ROUGE-2 recall
    aux_rouge2_p += scores[i]['rouge-2']['p'] #ROUGE-2 precision
    aux_rouge2_f += scores[i]['rouge-2']['f'] #ROUGE-2 F1 score

  # print(j, '{:5.4f}'.format(aux_rouge1/len(scores)))
  # print('{:5.4f}'.format(aux_rouge2/len(scores)))
  # print('{:5.4f}'.format(aux_fscore/len(scores)))

  aux2_rouge1_r.append(aux_rouge1_r/len(scores))
  aux2_rouge1_p.append(aux_rouge1_p/len(scores))
  aux2_rouge1_f.append(aux_rouge1_f/len(scores))
  aux2_rouge2_r.append(aux_rouge2_r/len(scores))
  aux2_rouge2_p.append(aux_rouge2_p/len(scores))
  aux2_rouge2_f.append(aux_rouge2_f/len(scores))

  aux_rouge1_r = 0
  aux_rouge1_p = 0
  aux_rouge1_f = 0
  aux_rouge2_r = 0
  aux_rouge2_p = 0
  aux_rouge2_f = 0

print('ROUGE-1 recall = {:5.4f}'.format(sum(aux2_rouge1_r)/len(foname)))
print('ROUGE-1 precision = {:5.4f}'.format(sum(aux2_rouge1_p)/len(foname)))
print('ROUGE-1 F1 score = {:5.4f}'.format(sum(aux2_rouge1_f)/len(foname)))
print('ROUGE-2 recall = {:5.4f}'.format(sum(aux2_rouge2_r)/len(foname)))
print('ROUGE-2 precision = {:5.4f}'.format(sum(aux2_rouge2_p)/len(foname)))
print('ROUGE-2 F1 score = {:5.4f}'.format(sum(aux2_rouge2_f)/len(foname)))

#np.save(common_path + 'ROUGE1_recall_DUC2001A_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_r)/len(foname))
#np.save(common_path + 'ROUGE1_F1score_DUC2001A_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_f)/len(foname))
#np.save(common_path + 'ROUGE1_precision_DUC2001A_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_p)/len(foname))
#np.save(common_path + 'ROUGE2_recall_DUC2001A_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_r)/len(foname))
#np.save(common_path + 'ROUGE2_precision_DUC2001A_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_p)/len(foname))
#np.save(common_path + 'ROUGE2_F1score_DUC2001A_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_f)/len(foname))

#np.save(common_path + 'ROUGE1_recall_DUC2001B_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_r)/len(foname))
#np.save(common_path + 'ROUGE1_F1score_DUC2001B_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_f)/len(foname))
#np.save(common_path + 'ROUGE1_precision_DUC2001B_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge1_p)/len(foname))
#np.save(common_path + 'ROUGE2_recall_DUC2001B_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_r)/len(foname))
#np.save(common_path + 'ROUGE2_precision_DUC2001B_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_p)/len(foname))
#np.save(common_path + 'ROUGE2_F1score_DUC2001B_sup_cl{}_pyrouge'.format(num_cl) + '.npy', sum(aux2_rouge2_f)/len(foname))


#np.save(common_path + 'ROUGE1_recall_DUC2001A_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge1_r)/len(foname))
#np.save(common_path + 'ROUGE1_precision_DUC2001A_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge1_p)/len(foname))
#np.save(common_path + 'ROUGE1_F1score_DUC2001A_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge1_f)/len(foname))
#np.save(common_path + 'ROUGE2_recall_DUC2001A_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge2_r)/len(foname))
#np.save(common_path + 'ROUGE2_precision_DUC2001A_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge2_p)/len(foname))
#np.save(common_path + 'ROUGE2_F1score_DUC2001A_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge2_f)/len(foname))

#np.save(common_path + 'ROUGE1_recall_DUC2001B_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge1_r)/len(foname))
#np.save(common_path + 'ROUGE1_F1score_DUC2001B_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge1_f)/len(foname))
#np.save(common_path + 'ROUGE1_precision_DUC2001B_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge1_p)/len(foname))
#np.save(common_path + 'ROUGE2_recall_DUC2001B_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge2_r)/len(foname))
#np.save(common_path + 'ROUGE2_precision_DUC2001B_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge2_p)/len(foname))
#np.save(common_path + 'ROUGE2_F1score_DUC2001B_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge2_f)/len(foname))

#np.save(common_path + 'ROUGE1_recall_DUC2002A_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge1_r)/len(foname))
#np.save(common_path + 'ROUGE1_precision_DUC2002A_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge1_p)/len(foname))
#np.save(common_path + 'ROUGE1_F1score_DUC2002A_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge1_f)/len(foname))
#np.save(common_path + 'ROUGE2_recall_DUC2002A_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge2_r)/len(foname))
#np.save(common_path + 'ROUGE2_precision_DUC2002A_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge2_p)/len(foname))
#np.save(common_path + 'ROUGE2_F1score_DUC2002A_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge2_f)/len(foname))

np.save(common_path + 'ROUGE1_recall_DUC2002B_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge1_r)/len(foname))
np.save(common_path + 'ROUGE1_precision_DUC2002B_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge1_p)/len(foname))
np.save(common_path + 'ROUGE1_F1score_DUC20012B_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge1_f)/len(foname))
np.save(common_path + 'ROUGE2_recall_DUC2002B_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge2_r)/len(foname))
np.save(common_path + 'ROUGE2_precision_DUC2002B_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge2_p)/len(foname))
np.save(common_path + 'ROUGE2_F1score_DUC2002B_sup_cl{}'.format(num_cl) + '.npy', sum(aux2_rouge2_f)/len(foname))
# Out:
# ROUGE-1 recall = 0.0151
# ROUGE-1 precision = 0.0176
# ROUGE-1 F1 score = 0.0152
# ROUGE-2 recall = 0.0005
# ROUGE-2 precision = 0.0004
# ROUGE-2 F1 score = 0.0004

# %%
# for DUC 2002 unsupervised (30 experiments)
common_path = '/content/gdrive/My Drive/Codigos_doctorado_unsupervised_best/'
scores = []
aux_rouge1_r = 0
aux_rouge1_p = 0
aux_rouge1_f = 0
aux_rouge2_r = 0
aux_rouge2_p = 0
aux_rouge2_f = 0

aux2_rouge1_r = []
aux2_rouge1_p = []
aux2_rouge1_f = []
aux2_rouge2_r = []
aux2_rouge2_p = []
aux2_rouge2_f = []

aux3_rouge1_r = 0
aux3_rouge1_p = 0
aux3_rouge1_f = 0
aux3_rouge2_r = 0
aux3_rouge2_p = 0
aux3_rouge2_f = 0

for z in range(30):

  for j in range(len(foname)):

    # print(j)
    # for DUC 2002 A
    hyp_path = common_path + 'summaries_for_ROUGE_pltrdy_A_DUC2002/' + 'CluAgglo_RoulD_resumenes_{}/'.format(z) + '{}_englishSyssum1.txt'.format(foname[j])
    ref_path = '/content/gdrive/My Drive/Codigos_doctorado_DUC2001/' + 'gold_standardA_DUC2002/' + '{}_englishReference1.txt'.format(foname[j])

    # for DUC 2002 B
    # hyp_path = common_path + 'summaries_for_ROUGE_pltrdy_B_DUC2002/' + 'CluAgglo_RoulD_resumenes_{}/'.format(z) + '{}_englishSyssum1.txt'.format(foname[j])
    # ref_path = '/content/gdrive/My Drive/Codigos_doctorado_DUC2001/' + 'gold_standardB_DUC2002/' + '{}_englishReference1.txt'.format(foname[j])
    
    from rouge import FilesRouge

    files_rouge = FilesRouge(hyp_path, ref_path)
    scores = files_rouge.get_scores()
    # or
    # scores = files_rouge.get_scores(avg=True)

    for i in range(len(scores)):
      # print(i)
      aux_rouge1_r += scores[i]['rouge-1']['r'] #ROUGE-1 recall
      aux_rouge1_p += scores[i]['rouge-1']['p'] #ROUGE-1 precision
      aux_rouge1_f += scores[i]['rouge-1']['f'] #ROUGE-1 F1 score
      aux_rouge2_r += scores[i]['rouge-2']['r'] #ROUGE-2 recall
      aux_rouge2_p += scores[i]['rouge-2']['p'] #ROUGE-2 precision
      aux_rouge2_f += scores[i]['rouge-2']['f'] #ROUGE-2 F1 score

    # print(j, '{:5.4f}'.format(aux_rouge1/len(scores)))
    # print('{:5.4f}'.format(aux_rouge2/len(scores)))
    # print('{:5.4f}'.format(aux_fscore/len(scores)))

    aux2_rouge1_r.append(aux_rouge1_r/len(scores))
    aux2_rouge1_p.append(aux_rouge1_p/len(scores))
    aux2_rouge1_f.append(aux_rouge1_f/len(scores))
    aux2_rouge2_r.append(aux_rouge2_r/len(scores))
    aux2_rouge2_p.append(aux_rouge2_p/len(scores))
    aux2_rouge2_f.append(aux_rouge2_f/len(scores))

    aux_rouge1_r = 0
    aux_rouge1_p = 0
    aux_rouge1_f = 0
    aux_rouge2_r = 0
    aux_rouge2_p = 0
    aux_rouge2_f = 0

  # print('Experiment: ', z)
  # print('ROUGE-1 = {:5.4f}'.format(sum(aux2_rouge1)/len(foname)))
  # print('ROUGE-2 = {:5.4f}'.format(sum(aux2_rouge2)/len(foname)))
  # print('F1 score = {:5.4f}'.format(sum(aux2_fscore)/len(foname)))

  np.save(common_path + 'ROUGE1_recall_DUC2002A_unsup{}'.format(i) + '.npy', sum(aux2_rouge1_r)/len(foname))
  np.save(common_path + 'ROUGE1_precision_DUC2002A_unsup{}'.format(i) + '.npy', sum(aux2_rouge1_p)/len(foname))
  np.save(common_path + 'ROUGE1_f1score_DUC2002A_unsup{}'.format(i) + '.npy', sum(aux2_rouge1_f)/len(foname))
  np.save(common_path + 'ROUGE2_recall_DUC2002A_unsup{}'.format(i) + '.npy', sum(aux2_rouge2_r)/len(foname))
  np.save(common_path + 'ROUGE2_precision_DUC2002A_unsup{}'.format(i) + '.npy', sum(aux2_rouge2_p)/len(foname))
  np.save(common_path + 'ROUGE2_f1score_DUC2002A_unsup{}'.format(i) + '.npy', sum(aux2_rouge2_f)/len(foname))

  # np.save(common_path + 'ROUGE1_recall_DUC2002B_unsup{}'.format(i) + '.npy', sum(aux2_rouge1_r)/len(foname))
  # np.save(common_path + 'ROUGE1_precision_DUC2002B_unsup{}'.format(i) + '.npy', sum(aux2_rouge1_p)/len(foname))
  # np.save(common_path + 'ROUGE1_f1score_DUC2002B_unsup{}'.format(i) + '.npy', sum(aux2_rouge1_f)/len(foname))
  # np.save(common_path + 'ROUGE2_recall_DUC2002B_unsup{}'.format(i) + '.npy', sum(aux2_rouge2_r)/len(foname))
  # np.save(common_path + 'ROUGE2_precision_DUC2002B_unsup{}'.format(i) + '.npy', sum(aux2_rouge2_p)/len(foname))
  # np.save(common_path + 'ROUGE2_f1score_DUC2002B_unsup{}'.format(i) + '.npy', sum(aux2_rouge2_f)/len(foname))

  aux3_rouge1_r += sum(aux2_rouge1_r)/len(foname)
  aux3_rouge1_p += sum(aux2_rouge1_p)/len(foname)
  aux3_rouge1_f += sum(aux2_rouge1_f)/len(foname)
  aux3_rouge2_r += sum(aux2_rouge2_r)/len(foname)
  aux3_rouge2_p += sum(aux2_rouge2_p)/len(foname)
  aux3_rouge2_f += sum(aux2_rouge2_f)/len(foname)

  aux2_rouge1_r = []
  aux2_rouge1_p = []
  aux2_rouge1_f = []
  aux2_rouge2_r = []
  aux2_rouge2_p = []
  aux2_rouge2_f = []

print('Average ROUGE1_recall:', aux3_rouge1_r/30)
print('Average ROUGE1_precision:', aux3_rouge1_p/30)
print('Average ROUGE1_f1score:', aux3_rouge1_f/30)
print('Average ROUGE2_recall:', aux3_rouge2_r/30)
print('Average ROUGE2_precision:', aux3_rouge2_p/30)
print('Average ROUGE2_f1score:', aux3_rouge2_f/30)
# Out:
# Average ROUGE1_recall: 0.08789601790877416
# Average ROUGE1_precision: 0.11506344775950211
# Average ROUGE1_f1score: 0.09117020272049645
# Average ROUGE2_recall: 0.01579070136490752
# Average ROUGE2_precision: 0.0197334704125651
# Average ROUGE2_f1score: 0.016289534326636983

# %%
np.load()
