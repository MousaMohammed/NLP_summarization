# %%
# !pip install numpy==1.16.2
# La versión 1.16.3 de numpy tiene allow_pickle = True

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
# !pip install easy-rouge

# %%
def summary_evaluation_ROUGEN(docs_per_sentence, gold_per_sentence, n_rouge):

  from rouge.rouge import rouge_n_sentence_level

  def prepare_results(r, p, f, n_rouge):
      return '\t{}:{:5.4f}\t{}: {:5.4f}\t{}: {:5.4f}'.format('ROUGE{}-recall'.format(n_rouge), r, 'ROUGE{}-precision'.format(n_rouge), p, 'ROUGE{}-F1 score'.format(n_rouge), f)

  j = 0
  RN_recall_total = []
  RN_precision_total = []
  RN_fscore_total = []

  # for j in range(len(docs_per_sentence)):
      
  RN_recall, RN_precision, RN_fscore = rouge_n_sentence_level(docs_per_sentence, gold_per_sentence, n_rouge, 1)
  RN_recall_total.append(RN_recall)
  RN_precision_total.append(RN_precision)
  RN_fscore_total.append(RN_fscore)
  
  print(prepare_results(RN_recall, RN_precision, RN_fscore, n_rouge))
  
  return RN_recall_total, RN_precision_total, RN_fscore_total

# %%
# import numpy as np
common_path = '/content/gdrive/My Drive/'
nrouge1 = 1
nrouge2 = 2
# sent_per_collection = open(common_path + 'toy_example2_easy_rouge_and_pltrdy/' + 'toy_example2_d1/' + 'd01_englishSyssum1.txt', 'r').readlines()
# sent_per_collection = open(common_path + 'toy_example2_easy_rouge_and_pltrdy/' + 'toy_example2_d2/' + 'd01_englishSyssum1.txt', 'r').readlines()
# sent_per_collection = open(common_path + 'toy_example2_easy_rouge_and_pltrdy/' + 'toy_example2_d3/' + 'd01_englishSyssum1.txt', 'r').readlines()
sent_per_collection = open(common_path + 'toy_example2_easy_rouge_and_pltrdy/' + 'toy_example2_d4/' + 'd01_englishSyssum1.txt', 'r').readlines()

gold_std = open(common_path + 'toy_example2_easy_rouge_and_pltrdy/' + 'toy_example2_model_summaries/' + 'd01_englishReference1.txt', 'r').readlines()
#R1_recall_total, R1_precision_total, R1_fscore_total = summary_evaluation_ROUGEN(sent_per_collection, gold_std, nrouge1)
#R2_recall_total, R2_precision_total, R2_fscore_total = summary_evaluation_ROUGEN(sent_per_collection, gold_std, nrouge2)
# print(R1_recall_total, R2_recall_total, R1_fscore_total)

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

aux = []
for i in range(len(gold_std)):
  aux.extend(word_tokenize(gold_std[i]))
aux2 = []
for i in range(len(sent_per_collection)):
  aux2.extend(word_tokenize(sent_per_collection[i]))

# %%
print(aux2)
# Out:
# ['Gorbachev', 'was', 'set', 'to', 'board', 'a', 'plane', 'in', 'the', 'Crimea', ',', 'where', 'he', 'was', 'vacationing', 'at', 'the', 'time', 'of', 'Monday', "'s", 'coup', ',', 'for', 'the', 'two-hour', 'flight', 'to', 'Moscow', ',', 'said', 'a', 'deputy', 'to', 'Russian', 'Defense', 'Minister', 'Konstantin', 'Kobets', '.', 'Earlier', 'reports', 'that', 'the', 'plane', 'had', 'already', 'taken', 'off', 'were', 'incorrect', ',', 'officials', 'said', '.', 'The', 'Soviet', 'leader', ',', 'in', 'a', 'statement', 'for', 'radio', 'and', 'television', ',', 'said', 'he', 'was', 'fully', 'in', 'command', 'of', 'the', 'situation', 'and', 'that', 'the', 'coup', 'leaders', 'would', 'bear', '``', 'full', 'responsibility', "''", 'for', 'their', 'actions', '.', 'In', 'the', 'United', 'States', ',', 'President', 'Bush', 'hailed', 'Gorbachev', "'s", 'return', 'to', 'power', 'and', 'said', 'the', 'coup', 'leaders', 'had', '``', 'underestimated', 'the', 'power', 'of', 'the', 'people', ',', 'underestim
# ...

# %%
print(aux)
# Out:
# ['The', 'camera', 'zooms', 'in', 'on', 'the', 'impassive', 'faces', 'of', 'the', 'two', 'men', 'last', 'seen', 'in', 'Gorbachev', "'s", 'office', '.', 'What', 'is', 'going', 'on', 'here', '?', 'OK', ',', 'it', "'s", 'a', 'hackneyed', 'device', 'that', 'would', 'only', 'work', 'in', 'the', 'movies', '.', 'The', 'Soviet', 'leader', ',', 'in', 'a', 'statement', 'for', 'radio', 'and', 'television', ',', 'said', 'he', 'was', 'fully', 'in', 'command', 'of', 'the', 'situation', 'and', 'that', 'the', 'coup', 'leaders', 'would', 'bear', '``', 'full', 'responsibility', "''", 'for', 'their', 'actions', '.', 'In', 'the', 'United', 'States', ',', 'President', 'Bush', 'hailed', 'Gorbachev', "'s", 'return', 'to', 'power', 'and', 'said', 'the', 'coup', 'leaders', 'had', '``', 'underestimated', 'the', 'power', 'of', 'the', 'people', ',', 'underestimated', 'what', 'a', 'taste', 'of', 'freedom', 'and', 'democracy', 'brings', '.', "''"]

# %%
import numpy as np

R1_recall_total, R1_precision_total, R1_fscore_total = summary_evaluation_ROUGEN(aux2, aux, nrouge1)
R2_recall_total, R2_precision_total, R2_fscore_total = summary_evaluation_ROUGEN(aux2, aux, nrouge2)

x = 'd4'

np.save(common_path + 'r1_recall_toy_example2_duc2002_{}'.format(x) + '.npy', R1_recall_total)
np.save(common_path + 'r1_precision_toy_example2_duc2002{}'.format(x) + '.npy', R1_precision_total)
np.save(common_path + 'r1_f1_score_toy_example2_duc2002{}'.format(x) + '.npy', R1_fscore_total)

np.save(common_path + 'r2_recall_toy_example2_duc2002{}'.format(x) + '.npy', R2_recall_total)
np.save(common_path + 'r2_precision_toy_example2_duc2002{}'.format(x) + '.npy', R2_precision_total)
np.save(common_path + 'r2_f1_score_toy_example2_duc2002{}'.format(x) + '.npy', R2_fscore_total)

print(R1_recall_total, R2_recall_total, R1_fscore_total)
# Out:
# 	ROUGE1-recall:0.7544	ROUGE1-precision: 0.6667	ROUGE1-F1 score: 0.6667
# 	ROUGE2-recall:0.6637	ROUGE2-precision: 0.5859	ROUGE2-F1 score: 0.5859
# [0.7543859649122807] [0.6637168141592921] [0.6666666666666666]

# %%
## Remember that equivalent experiment for paper ACL 2020 are the following:
# d1 = Output Document 3
# d2 = Output Document 4
# d3 = Output Document 1
# d4 = Output Document 2
