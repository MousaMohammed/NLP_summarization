# %%
# !pip install numpy==1.16.2
# La versión 1.16.3 de numpy tiene allow_pickle = True

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# from https://github.com/pltrdy/rouge
# !pip install rouge

# %%
common_path = '/content/gdrive/My Drive/'

hyp_path = common_path + 'toy_example2_easy_rouge_and_pltrdy/toy_example2_d4/' + 'd01_englishSyssum1.txt'
ref_path = common_path + 'toy_example2_easy_rouge_and_pltrdy/toy_example2_model_summaries/' + 'd01_englishReference1.txt'

# %%
from rouge import FilesRouge

files_rouge = FilesRouge(hyp_path, ref_path)
scores = files_rouge.get_scores()
print(scores)
# Out:
# [{'rouge-1': {'f': 0.13636363186983486, 'p': 0.10344827586206896, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.11518513182477638, 'p': 0.10344827586206896, 'r': 0.2}}, {'rouge-1': {'f': 0.1333333284222224, 'p': 0.15384615384615385, 'r': 0.11764705882352941}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.12883263009824591, 'p': 0.15384615384615385, 'r': 0.11764705882352941}}, {'rouge-1': {'f': 0.999999995, 'p': 1.0, 'r': 1.0}, 'rouge-2': {'f': 0.999999995, 'p': 1.0, 'r': 1.0}, 'rouge-l': {'f': 0.9999999999995, 'p': 1.0, 'r': 1.0}}, {'rouge-1': {'f': 0.999999995, 'p': 1.0, 'r': 1.0}, 'rouge-2': {'f': 0.999999995, 'p': 1.0, 'r': 1.0}, 'rouge-l': {'f': 0.9999999999995, 'p': 1.0, 'r': 1.0}}]
