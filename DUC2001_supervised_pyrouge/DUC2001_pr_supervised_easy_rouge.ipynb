# %%
# !pip install numpy==1.16.2
# La versión 1.16.3 de numpy tiene allow_pickle = True

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
# !pip install easy-rouge

# %%
def summary_evaluation_ROUGEN(docs_per_sentence, gold_per_sentence, n_rouge):

  from rouge.rouge import rouge_n_sentence_level

  def prepare_results(r, p, f, n_rouge):
      return '\t{}:{:5.4f}\t{}: {:5.4f}\t{}: {:5.4f}'.format('ROUGE{}-recall'.format(n_rouge), r, 'ROUGE{}-precision'.format(n_rouge), p, 'ROUGE{}-F1 score'.format(n_rouge), f)

  # j = 0
  RN_recall_total = []
  RN_precision_total = []
  RN_fscore_total = []

  for j in range(len(docs_per_sentence)):
      
    RN_recall, RN_precision, RN_fscore = rouge_n_sentence_level(docs_per_sentence[j], gold_per_sentence[j], n_rouge, 1)
    RN_recall_total.append(RN_recall)
    RN_precision_total.append(RN_precision)
    RN_fscore_total.append(RN_fscore)
  
    print(prepare_results(RN_recall, RN_precision, RN_fscore, n_rouge))
  
  return RN_recall_total, RN_precision_total, RN_fscore_total

# %%
import numpy as np
common_path = "/content/gdrive/My Drive/Codigos_doctorado_DUC2001/"
sent_per_collection = np.load(common_path + 'summaries_per_collection_DUC2001_balanced_test_30collectionALL_pyrouge' + '.npy')
hr_golda = np.load(common_path + 'documentos_por_palabras_golda_testing_doubles' + '.npy')
hr_goldb = np.load(common_path + 'documentos_por_palabras_goldb_testing_doubles' + '.npy')
# sac3 = np.load(common_path + 'ext2_sent_num_per_set_2001' + '.npy')

# %%
print(len(sent_per_collection[4][0]), len(hr_golda))
# Out:
# 30 30

# %%
i = 4
nrouge1 = 1
nrouge2 = 2
gold_std = hr_golda
R1_recall_total_A, R1_precision_total_A, R1_fscore_total_A = summary_evaluation_ROUGEN(sent_per_collection[4][0], gold_std, nrouge1)
R2_recall_total_A, R2_precision_total_A, R2_fscore_total_A = summary_evaluation_ROUGEN(sent_per_collection[4][0], gold_std, nrouge2)

# save results  
np.save(common_path + 'R1_recall_oraciones_DUC2001_classifier_test_30collectionA_pyrouge_{}'.format(i) + '.npy', R1_recall_total_A)
np.save(common_path + 'R1_precision_oraciones_DUC2001_classifier_test_30collectionA_pyrouge_{}'.format(i) + '.npy', R1_precision_total_A)
np.save(common_path + 'R1_fscore_oraciones_DUC2001_classifier_test_30collectionA_pyrouge_{}'.format(i) + '.npy', R1_fscore_total_A)

np.save(common_path + 'R2_recall_oraciones_DUC2001_classifier_test_30collectionA_pyrouge_{}'.format(i) + '.npy', R2_recall_total_A)
np.save(common_path + 'R2_precision_oraciones_DUC2001_classifier_test_30collectionA_pyrouge_{}'.format(i) + '.npy', R2_precision_total_A)
np.save(common_path + 'R2_fscore_oraciones_DUC2001_classifier_test_30collectionA_pyrouge_{}'.format(i) + '.npy', R2_fscore_total_A)
# Out:
# 	ROUGE1-recall:0.1696	ROUGE1-precision: 0.2676	ROUGE1-F1 score: 0.2676
# 	ROUGE1-recall:0.1905	ROUGE1-precision: 0.3243	ROUGE1-F1 score: 0.3243
# 	ROUGE1-recall:0.2018	ROUGE1-precision: 0.2619	ROUGE1-F1 score: 0.2619
# 	ROUGE1-recall:0.2544	ROUGE1-precision: 0.3372	ROUGE1-F1 score: 0.3372
# 	ROUGE1-recall:0.1416	ROUGE1-precision: 0.2500	ROUGE1-F1 score: 0.2500
# 	ROUGE1-recall:0.2035	ROUGE1-precision: 0.3333	ROUGE1-F1 score: 0.3333
# 	ROUGE1-recall:0.3551	ROUGE1-precision: 0.2992	ROUGE1-F1 score: 0.2992
# 	ROUGE1-recall:0.0940	ROUGE1-precision: 0.0791	ROUGE1-F1 score: 0.0791
# 	ROUGE1-recall:0.2188	ROUGE1-precision: 0.3457	ROUGE1-F1 score: 0.3457
# 	ROUGE1-recall:0.0909	ROUGE1-precision: 0.1964	ROUGE1-F1 score: 0.1964
# 	ROUGE1-recall:0.2735	ROUGE1-precision: 0.3441	ROUGE1-F1 score: 0.3441
# 	ROUGE1-recall:0.2521	ROUGE1-precision: 0.3125	ROUGE1-F1 score: 0.3125
# 	ROUGE1-recall:0.2385	ROUGE1-precision: 0.2080	ROUGE1-F1 score: 0.2080
# ...

# %%
i = 4
nrouge1 = 1
nrouge2 = 2
gold_std = hr_goldb
R1_recall_total_B, R1_precision_total_B, R1_fscore_total_B = summary_evaluation_ROUGEN(sent_per_collection[4][0], gold_std, nrouge1)
R2_recall_total_B, R2_precision_total_B, R2_fscore_total_B = summary_evaluation_ROUGEN(sent_per_collection[4][0], gold_std, nrouge2)

# save results  
np.save(common_path + 'R1_recall_oraciones_DUC2001_classifier_test_30collectionB_pyrouge_{}'.format(i) + '.npy', R1_recall_total_B)
np.save(common_path + 'R1_precision_oraciones_DUC2001_classifier_test_30collectionB_pyrouge_{}'.format(i) + '.npy', R1_precision_total_B)
np.save(common_path + 'R1_fscore_oraciones_DUC2001_classifier_test_30collectionB_pyrouge_{}'.format(i) + '.npy', R1_fscore_total_B)

np.save(common_path + 'R2_recall_oraciones_DUC2001_classifier_test_30collectionB_pyrouge_{}'.format(i) + '.npy', R2_recall_total_B)
np.save(common_path + 'R2_precision_oraciones_DUC2001_classifier_test_30collectionB_pyrouge_{}'.format(i) + '.npy', R2_precision_total_B)
np.save(common_path + 'R2_fscore_oraciones_DUC2001_classifier_test_30collectionB_pyrouge_{}'.format(i) + '.npy', R2_fscore_total_B)
# Out:
# 	ROUGE1-recall:0.1293	ROUGE1-precision: 0.2113	ROUGE1-F1 score: 0.2113
# 	ROUGE1-recall:0.1818	ROUGE1-precision: 0.2973	ROUGE1-F1 score: 0.2973
# 	ROUGE1-recall:0.2545	ROUGE1-precision: 0.3333	ROUGE1-F1 score: 0.3333
# 	ROUGE1-recall:0.2170	ROUGE1-precision: 0.2674	ROUGE1-F1 score: 0.2674
# 	ROUGE1-recall:0.1441	ROUGE1-precision: 0.2500	ROUGE1-F1 score: 0.2500
# 	ROUGE1-recall:0.1681	ROUGE1-precision: 0.2754	ROUGE1-F1 score: 0.2754
# 	ROUGE1-recall:0.2281	ROUGE1-precision: 0.2047	ROUGE1-F1 score: 0.2047
# 	ROUGE1-recall:0.1739	ROUGE1-precision: 0.1439	ROUGE1-F1 score: 0.1439
# 	ROUGE1-recall:0.1811	ROUGE1-precision: 0.2840	ROUGE1-F1 score: 0.2840
# 	ROUGE1-recall:0.1415	ROUGE1-precision: 0.2679	ROUGE1-F1 score: 0.2679
# 	ROUGE1-recall:0.2149	ROUGE1-precision: 0.2796	ROUGE1-F1 score: 0.2796
# 	ROUGE1-recall:0.1712	ROUGE1-precision: 0.1979	ROUGE1-F1 score: 0.1979
# 	ROUGE1-recall:0.2522	ROUGE1-precision: 0.2320	ROUGE1-F1 score: 0.2320
# ...

# %%
print(((sum(R1_recall_total_A)/30) + (sum(R1_recall_total_B)/30))/2)
print(((sum(R1_precision_total_A)/30) + (sum(R1_precision_total_B)/30))/2)
print(((sum(R1_fscore_total_A)/30) + (sum(R1_fscore_total_B)/30))/2)

print(((sum(R2_recall_total_A)/30) + (sum(R2_recall_total_B)/30))/2)
print(((sum(R2_precision_total_A)/30) + (sum(R2_precision_total_B)/30))/2)
print(((sum(R2_fscore_total_A)/30) + (sum(R2_fscore_total_B)/30))/2)
# Out:
# 0.21173183494740605
# 0.25475729409248266
# 0.25475729409248266
# 0.02101051818409267
# 0.024499965352539604
# 0.024499965352539604
